# %% [markdown]
# <a href="https://colab.research.google.com/github/JoThePOkeMOn/Computational-Optimization-and-Applications-Minor/blob/main/Deeplearning_implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Libraries

# %%
import tensorflow as tf
from tensorflow import keras
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler
import numpy as np

# %% [markdown]
# # Load Dataset

# %%
iris = load_iris()
X = iris.data
y = iris.target
# Preprocess the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
print(X.shape)
# Out:
# (150, 4)

# %% [markdown]
# # Build nEURAL Network

# %%
# Build the neural network model
model = keras.Sequential([
    keras.layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(3, activation='softmax')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compile the model with Adam optimizer and categorical cross-entropy loss
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=16, validation_split=0.2,verbose=1)
# Out:
# Epoch 1/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.3542 - loss: 1.0383 - val_accuracy: 0.8333 - val_loss: 0.9130
# Epoch 2/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.4271 - loss: 1.0287 - val_accuracy: 0.8333 - val_loss: 0.8406
# Epoch 3/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5833 - loss: 0.8968 - val_accuracy: 0.8333 - val_loss: 0.7756
# Epoch 4/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6875 - loss: 0.8111 - val_accuracy: 0.8750 - val_loss: 0.7181
# Epoch 5/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7292 - loss: 0.7603 - val_accuracy: 0.8750 - val_loss: 0.6645
# Epoch 6/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7188 - loss: 0.7328 - val_accuracy: 0.8750 - val_loss: 0.6187
# Epoch 7/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7083 - loss: 0.6746 - val_accuracy: 0.8750 - val_loss: 0.5775
# Epoch 8/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7292 - loss: 0.6336 - val_accuracy: 0.8750 - val_loss: 0.5391
# Epoch 9/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7500 - loss: 0.6040 - val_accuracy: 0.8750 - val_loss: 0.5075
# Epoch 10/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7604 - loss: 0.5908 - val_accuracy: 0.8750 - val_loss: 0.4817
# Epoch 11/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7812 - loss: 0.4990 - val_accuracy: 0.8750 - val_loss: 0.4575
# Epoch 12/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7708 - loss: 0.5255 - val_accuracy: 0.8750 - val_loss: 0.4331
# Epoch 13/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7917 - loss: 0.5105 - val_accuracy: 0.8750 - val_loss: 0.4116
# Epoch 14/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7396 - loss: 0.4772 - val_accuracy: 0.8750 - val_loss: 0.3919
# Epoch 15/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8438 - loss: 0.4410 - val_accuracy: 0.8750 - val_loss: 0.3770
# Epoch 16/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7917 - loss: 0.4362 - val_accuracy: 0.8750 - val_loss: 0.3643
# Epoch 17/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8229 - loss: 0.4285 - val_accuracy: 0.8750 - val_loss: 0.3542
# Epoch 18/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8125 - loss: 0.3755 - val_accuracy: 0.9167 - val_loss: 0.3445
# Epoch 19/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8333 - loss: 0.4294 - val_accuracy: 0.9167 - val_loss: 0.3349
# Epoch 20/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8125 - loss: 0.4149 - val_accuracy: 0.9167 - val_loss: 0.3284
# Epoch 21/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8125 - loss: 0.3973 - val_accuracy: 0.9167 - val_loss: 0.3231
# Epoch 22/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8646 - loss: 0.3685 - val_accuracy: 0.9167 - val_loss: 0.3127
# Epoch 23/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8333 - loss: 0.3728 - val_accuracy: 0.9167 - val_loss: 0.3061
# Epoch 24/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8021 - loss: 0.4088 - val_accuracy: 0.9167 - val_loss: 0.2996
# Epoch 25/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8750 - loss: 0.3369 - val_accuracy: 0.9167 - val_loss: 0.2929
# Epoch 26/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8750 - loss: 0.3332 - val_accuracy: 0.9167 - val_loss: 0.2848
# Epoch 27/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8854 - loss: 0.3511 - val_accuracy: 0.9167 - val_loss: 0.2785
# Epoch 28/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8750 - loss: 0.3142 - val_accuracy: 0.9167 - val_loss: 0.2721
# Epoch 29/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8542 - loss: 0.3365 - val_accuracy: 0.9167 - val_loss: 0.2663
# Epoch 30/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8438 - loss: 0.3264 - val_accuracy: 0.9167 - val_loss: 0.2629
# Epoch 31/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8854 - loss: 0.2902 - val_accuracy: 0.9167 - val_loss: 0.2581
# Epoch 32/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8542 - loss: 0.3022 - val_accuracy: 0.9167 - val_loss: 0.2476
# Epoch 33/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8646 - loss: 0.3296 - val_accuracy: 0.9167 - val_loss: 0.2425
# Epoch 34/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.
# Epoch 76/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9688 - loss: 0.1487 - val_accuracy: 0.9583 - val_loss: 0.1449
# Epoch 77/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9479 - loss: 0.1556 - val_accuracy: 0.9583 - val_loss: 0.1487
# Epoch 78/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9479 - loss: 0.1423 - val_accuracy: 0.9583 - val_loss: 0.1455
# Epoch 79/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9271 - loss: 0.1519 - val_accuracy: 0.9583 - val_loss: 0.1415
# Epoch 80/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9167 - loss: 0.1578 - val_accuracy: 0.9583 - val_loss: 0.1412
# Epoch 81/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9167 - loss: 0.2120 - val_accuracy: 0.9583 - val_loss: 0.1418
# Epoch 82/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9688 - loss: 0.1211 - val_accuracy: 0.9583 - val_loss: 0.1448
# Epoch 83/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9583 - loss: 0.1269 - val_accuracy: 0.9583 - val_loss: 0.1533
# Epoch 84/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9479 - loss: 0.1161 - val_accuracy: 0.9583 - val_loss: 0.1523
# Epoch 85/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9479 - loss: 0.1282 - val_accuracy: 0.9583 - val_loss: 0.1456
# Epoch 86/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9479 - loss: 0.1853 - val_accuracy: 0.9583 - val_loss: 0.1378
# Epoch 87/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9479 - loss: 0.1381 - val_accuracy: 0.9583 - val_loss: 0.1348
# Epoch 88/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9271 - loss: 0.1391 - val_accuracy: 0.9583 - val_loss: 0.1381
# Epoch 89/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9479 - loss: 0.1516 - val_accuracy: 0.9583 - val_loss: 0.1321
# Epoch 90/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9375 - loss: 0.1590 - val_accuracy: 0.9583 - val_loss: 0.1298
# Epoch 91/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9583 - loss: 0.1087 - val_accuracy: 0.9583 - val_loss: 0.1221
# Epoch 92/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9375 - loss: 0.1454 - val_accuracy: 0.9583 - val_loss: 0.1216
# Epoch 93/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9271 - loss: 0.1434 - val_accuracy: 0.9583 - val_loss: 0.1241
# Epoch 94/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9479 - loss: 0.1310 - val_accuracy: 0.9583 - val_loss: 0.1237
# Epoch 95/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9062 - loss: 0.2486 - val_accuracy: 0.9583 - val_loss: 0.1270
# Epoch 96/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9375 - loss: 0.1291 - val_accuracy: 0.9583 - val_loss: 0.1339
# Epoch 97/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9271 - loss: 0.1458 - val_accuracy: 0.9583 - val_loss: 0.1337
# Epoch 98/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9479 - loss: 0.1177 - val_accuracy: 0.9583 - val_loss: 0.1284
# Epoch 99/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9792 - loss: 0.1050 - val_accuracy: 0.9583 - val_loss: 0.1270
# Epoch 100/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9375 - loss: 0.1668 - val_accuracy: 0.9583 - val_loss: 0.1210

# %%
# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f'Test accuracy: {test_acc:.4f}')
print("Classification Report:")
y_pred = np.argmax(model.predict(X_test), axis=1)
print(classification_report(y_test, y_pred))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0534
# Test accuracy: 1.0000
# Classification Report:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00         9
#            2       1.00      1.00      1.00        11
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %%
#confusion matrix
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# false positives, false negatives, true positives, true negatives
# For multi-class, you might want per-class metrics
cm = confusion_matrix(y_test, y_pred)
# Out:
# Confusion Matrix:
# [[10  0  0]
#  [ 0  9  0]
#  [ 0  0 11]]

# %%
# Get per-class metrics
for i in range(len(cm)):
    tp = cm[i, i]
    fp = cm[:, i].sum() - tp
    fn = cm[i, :].sum() - tp
    tn = cm.sum() - (tp + fp + fn)

    precision = tp / (tp + fp) if (tp + fp) > 0 else 0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

print(f"Class {i}: Precision={precision:.3f}, Recall={recall:.3f}, F1={f1:.3f}")

  # tru positives, true negatives, false positives, false negatives
print(f'True Positives: {tp}')
print(f'True Negatives: {tn}')
print(f'False Positives: {fp}')
print(f'False Negatives: {fn}')
# tru positive rate (sensitivity) and true negative rate (specificity)
tpr = tp / (tp + fn) if (tp + fn) > 0 else 0
tnr = tn / (tn + fp) if (tn + fp) > 0 else 0
print(f'True Positive Rate (Sensitivity): {tpr:.4f}')
print(f'True Negative Rate (Specificity): {tnr:.4f}')
# Out:
# Class 2: Precision=1.000, Recall=1.000, F1=1.000
# True Positives: 11
# True Negatives: 19
# False Positives: 0
# False Negatives: 0
# True Positive Rate (Sensitivity): 1.0000
# True Negative Rate (Specificity): 1.0000

# %%
# Region of convergence plot
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Loss curve plot- training and validation loss curves to visualize convergence and potential overfitting
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
